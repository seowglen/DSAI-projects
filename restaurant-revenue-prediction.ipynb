# %% [markdown]
# # NOTE: THIS PROJECT IS STILL IN PROGRESS.
#
# # Predicting the Revenue of restaurants using Machine Learning
#
# In this notebook, we will predicting the revenue of restaurants with a given dataset with NaN values and non-number columns. Time Series Regression
#
# ## Problem
#
# How well can we predict the future revenue of a restaurant, given its characteristics previous examples of how much similar revenues a restaurant generates?

# %% [markdown]
# ## Data
#
# 1. Id : Restaurant id.
# 2. Open Date : opening date for a restaurant
# 3. City : City that the restaurant is in. Note that there are unicode in the names.
# 4. City Group: Type of the city. Big cities, or Other.
# 5. Type: Type of the restaurant. FC: Food Court, IL: Inline, DT: Drive Thru, MB: Mobile
# 6. P1, P2 - P37: There are three categories of these obfuscated data. Demographic data are gathered from third party providers with GIS systems. These include population in any given area, age and gender distribution, development scales. Real estate data mainly relate to the m2 of the location, front facade of the location, car park availability. Commercial data mainly include the existence of points of interest including schools, banks, other QSR operators.
# 7. Revenue: The revenue column indicates a (transformed) revenue of the restaurant in a given year and is the target of predictive analysis. Please note that the values are transformed so they don't mean real dollar values.

# %% [markdown]
# ## Evaluation metric
#
# We will use the root mean squared log error (RMSLE) of the data trained by the RandomForestRegressor model for evaluation.

# %%
# Import data analysis tools 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
# Import the training set
df = pd.read_csv("restaurant-data/train.csv",
                low_memory=False,
                 parse_dates=["Open Date"])

# %%
df.head().T
# Out:
#                               0                    1                    2  \
# Id                            0                    1                    2
# Open Date   1999-07-17 00:00:00  2008-02-14 00:00:00  2013-03-09 00:00:00
# City                   İstanbul               Ankara           Diyarbakır
# City Group           Big Cities           Big Cities                Other
# Type                         IL                   FC                   IL
# P1                            4                    4                    2
# P2                            5                    5                    4
# P3                            4                    4                    2
# P4                            4                    4                    5
# P5                            2                    1                    2
# P6                            2                    2                    3
# P7                            5                    5                    5
# P8                            4                    5                    5
# P9                            5                    5                    5
# P10                           5                    5                    5
# P11                           3                    1                    2
# P12                           5                    5                    5
# P13                           5                    5                    5
# P14                           1                    0                    0
# P15                           2                    0                    0
# P16                           2                    0                    0
# P17                           2                    0                    0
# P18                           4                    0                    0
# P19                           5                    3                    1
# P20                           4                    2                    1
# P21                           1                    1                    1
# P22                           3                    3                    1
# P23                           3                    2                    1
# P24                           1                    0                    0
# P25                           1                    0                    0
# P26                           1                    0                    0
# P27                           4                    0                    0
# P28                           2                    3                    1
# P29                           3                    3                    3
# P30                           5                    0                    0
# P31                           3                    0                    0
# P32                           4                    0                    0
# P33                           5                    0                    0
# P34                           5                    0                    0
# P35                           4                    0                    0
# P36                           3                    0                    0
# P37                           4                    0                    0
# revenue             5.65375e+06          6.92313e+06          2.05538e+06
#
#                               3                    4
# Id                            3                    4
# Open Date   2012-02-02 00:00:00  2009-05-09 00:00:00
# City                      Tokat            Gaziantep
# City Group                Other                Other
# Type                         IL                   IL
# P1                            6                    3
# P2                          4.5                    4
# P3                            6                    3
# P4                            6                    4
# P5                            4                    2
# P6                            4                    2
# P7                           10                    5
# P8                            8                    5
# P9                           10                    5
# P10                          10                    5
# P11                           8                    2
# P12                          10                    5
# P13                         7.5                    5
# P14                           6                    2
# P15                           4                    1
# P16                           9                    2
# P17                           3                    1
# P18                          12                    4
# P19                          20                    2
# P20                          12                    2
# P21                           6                    1
# P22                           1                    2
# P23                          10                    1
# P24                           2                    2
# P25                           2                    3
# P26                         2.5                    3
# P27                         2.5                    5
# P28                         2.5                    1
# P29                         7.5                    3
# P30                          25                    5
# P31                          12                    1
# P32                          10                    3
# P33                           6                    2
# P34                          18                    3
# P35                          12                    4
# P36                          12                    3
# P37                           6                    3
# revenue             2.67551e+06          4.31672e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          137 non-null    int64
#  1   Open Date   137 non-null    datetime64[ns]
#  2   City        137 non-null    object
#  3   City Group  137 non-null    object
#  4   Type        137 non-null    object
#  5   P1          137 non-null    int64
#  6   P2          137 non-null    float64
#  7   P3          137 non-null    float64
#  8   P4          137 non-null    float64
#  9   P5          137 non-null    int64
#  10  P6          137 non-null    int64
#  11  P7          137 non-null    int64
#  12  P8          137 non-null    int64
#  13  P9          137 non-null    int64
#  14  P10         137 non-null    int64
#  15  P11         137 non-null    int64
#  16  P12         137 non-null    int64
#  17  P13         137 non-null    float64
#  18  P14         137 non-null    int64
#  19  P15         137 non-null    int64
#  20  P16         137 non-null    int64
#  21  P17         137 non-null    int64
#  22  P18         137 non-null    int64
#  23  P19         137 non-null    int64
#  24  P20         137 non-null    int64
#  25  P21         137 non-null    int64
#  26  P22         137 non-null    int64
#  27  P23         137 non-null    int64
#  28  P24         137 non-null    int64
#  29  P25         137 non-null    int64
#  30  P26         137 non-null    float64
#  31  P27         137 non-null    float64
#  32  P28         137 non-null    float64
#  33  P29         137 non-null    float64
#  34  P30         137 non-null    int64
#  35  P31         137 non-null    int64
#  36  P32         137 non-null    int64
#  37  P33         137 non-null    int64
#  38  P34         137 non-null    int64
#  39  P35         137 non-null    int64
#  40  P36         137 non-null    int64
#  41  P37         137 non-null    int64
#  42  revenue     137 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(30), object(3)
# memory usage: 46.1+ KB

# %%
df.isna().sum()
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# revenue       0
# dtype: int64

# %%
# Sort dataframe by open date
df.sort_values(by=["Open Date"], inplace=True, ascending=True)
df['Open Date'].head(20)
# Out:
# 35    1996-05-08
# 122   1997-04-10
# 28    1998-01-28
# 112   1998-03-14
# 64    1998-07-13
# 83    1998-08-12
# 54    1999-06-05
# 0     1999-07-17
# 27    1999-10-09
# 99    1999-12-18
# 16    2000-01-07
# 85    2000-01-07
# 92    2002-11-01
# 131   2002-11-06
# 102   2004-09-11
# 44    2004-10-13
# 121   2004-11-13
# 124   2005-08-18
# 75    2005-10-15
# 81    2005-12-16
# Name: Open Date, dtype: datetime64[ns]

# %%
# Copy dataframe
df_tmp = df.copy()

# %%
# Add datetime parameters for saledate
df_tmp["reveuneYear"] = df_tmp['Open Date'].dt.year
df_tmp["revenueMonth"] = df_tmp['Open Date'].dt.month
df_tmp["revenueDay"] = df_tmp['Open Date'].dt.day
df_tmp["revenueDayofweek"] = df_tmp['Open Date'].dt.dayofweek
df_tmp["revenueDayofyear"] = df_tmp['Open Date'].dt.dayofyear

# Drop original saledate
df_tmp.drop("Open Date", axis=1, inplace=True)

# %%
df_tmp.head().T
# Out:
#                           35           122          28           112  \
# Id                         35          122           28          112
# City                    Adana     İstanbul     İstanbul     İstanbul
# City Group              Other   Big Cities   Big Cities   Big Cities
# Type                       IL           IL           IL           IL
# P1                          4           12            4            4
# P2                          5          7.5            5            5
# P3                          4            6            4            5
# P4                          3          7.5            4            4
# P5                          1            2            1            1
# P6                          2            8            3            5
# P7                          5           10            5            5
# P8                          4            8            5            5
# P9                          4            8            4            4
# P10                         5            8            4            4
# P11                         5           10            2            2
# P12                         4            6            4            4
# P13                         5            6            4            4
# P14                         2           15            3            3
# P15                         2            8            4            4
# P16                         4           12            4            2
# P17                         2            6            2            1
# P18                         4            9            4            4
# P19                         5           25            5            2
# P20                         5           15            5            3
# P21                         4            9            2            2
# P22                         3            5            4            2
# P23                         5           15            3            1
# P24                         3            6            5            3
# P25                         3           10            3            3
# P26                         3           10            4            4
# P27                         4            5            2            5
# P28                         3         12.5            4            3
# P29                         2          2.5            2            3
# P30                         4           25            3            3
# P31                         1           15            5            2
# P32                         3           25            5            1
# P33                         3            6            2            2
# P34                         3           18            3            2
# P35                         4            3            5            1
# P36                         3           16            4            3
# P37                         3            6            4            3
# revenue           3.90388e+06  4.28664e+06  4.70594e+06  3.78423e+06
# reveuneYear              1996         1997         1998         1998
# revenueMonth                5            4            1            3
# revenueDay                  8           10           28           14
# revenueDayofweek            2            3            2            5
# revenueDayofyear          129          100           28           73
#
#                           64
# Id                         64
# City                 İstanbul
# City Group         Big Cities
# Type                       IL
# P1                         12
# P2                        7.5
# P3                          6
# P4                          6
# P5                          2
# P6                          8
# P7                         10
# P8                         10
# P9                         10
# P10                        10
# P11                         4
# P12                        10
# P13                       7.5
# P14                        15
# P15                        10
# P16                        15
# P17                        15
# P18                        12
# P19                        10
# P20                         9
# P21                         6
# P22                         3
# P23                         5
# P24                        10
# P25                        10
# P26                      12.5
# P27                         5
# P28                         5
# P29                       7.5
# P30                        20
# P31                        15
# P32                        25
# P33                         4
# P34                        24
# P35                        15
# P36                        20
# P37                         6
# revenue           2.55125e+06
# reveuneYear              1998
# revenueMonth                7
# revenueDay                 13
# revenueDayofweek            0
# revenueDayofyear          194

# %%
# Convert non numeric objects to categories
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# %%
df_tmp.head(20)
# Out:
#       Id        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  P34  \
# 35    35       Adana       Other   IL   4  5.0  4.0  3.0   1   2  ...    3
# 122  122    İstanbul  Big Cities   IL  12  7.5  6.0  7.5   2   8  ...   18
# 28    28    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   1   3  ...    3
# 112  112    İstanbul  Big Cities   IL   4  5.0  5.0  4.0   1   5  ...    2
# 64    64    İstanbul  Big Cities   IL  12  7.5  6.0  6.0   2   8  ...   24
# 83    83    İstanbul  Big Cities   IL   2  4.0  4.0  4.0   2   5  ...    4
# 54    54       Muğla       Other   IL   2  4.0  5.0  4.0   1   1  ...    0
# 0      0    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...    5
# 27    27       Bursa       Other   FC   4  5.0  4.0  3.0   1   2  ...    0
# 99    99    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   4  ...    5
# 16    16    İstanbul  Big Cities   FC   3  5.0  4.0  4.0   2   5  ...    0
# 85    85    İstanbul  Big Cities   FC   3  5.0  4.0  4.0   2   5  ...    0
# 92    92    İstanbul  Big Cities   FC  12  7.5  7.5  6.0   2  10  ...    0
# 131  131      Ankara  Big Cities   FC   3  4.0  4.0  5.0   3   4  ...    0
# 102  102  Diyarbakır       Other   FC   4  5.0  2.0  5.0   2   2  ...    0
# 44    44      Ankara  Big Cities   IL   2  3.0  5.0  3.0   1   5  ...    3
# 121  121       İzmir  Big Cities   FC   2  4.0  4.0  4.0   2   3  ...    0
# 124  124      Ankara  Big Cities   DT   1  3.0  0.0  5.0   5   5  ...    0
# 75    75    İstanbul  Big Cities   FC   5  5.0  4.0  5.0   1   4  ...    0
# 81    81    İstanbul  Big Cities   FC   2  4.0  4.0  4.0   1   3  ...    0
#
#      P35  P36  P37     revenue  reveuneYear  revenueMonth  revenueDay  \
# 35     4    3    3   3903884.0         1996             5           8
# 122    3   16    6   4286645.0         1997             4          10
# 28     5    4    4   4705945.0         1998             1          28
# 112    1    3    3   3784230.0         1998             3          14
# 64    15   20    6   2551252.0         1998             7          13
# 83     4    5    3   5966193.0         1998             8          12
# 54     0    0    0   4651866.0         1999             6           5
# 0      4    3    4   5653753.0         1999             7          17
# 27     0    0    0   5435276.0         1999            10           9
# 99     5    5    3  13575224.0         1999            12          18
# 16     0    0    0  19696939.0         2000             1           7
# 85     0    0    0   7495092.0         2000             1           7
# 92     0    0    0   6782425.0         2002            11           1
# 131    0    0    0   3199619.0         2002            11           6
# 102    0    0    0   2738052.0         2004             9          11
# 44     4    3    4   4264176.0         2004            10          13
# 121    0    0    0   3445076.0         2004            11          13
# 124    0    0    0   3810007.0         2005             8          18
# 75     0    0    0  16549064.0         2005            10          15
# 81     0    0    0   4066618.0         2005            12          16
#
#      revenueDayofweek  revenueDayofyear
# 35                  2               129
# 122                 3               100
# 28                  2                28
# 112                 5                73
# 64                  0               194
# 83                  2               224
# 54                  5               156
# 0                   5               198
# 27                  5               282
# 99                  5               352
# 16                  4                 7
# 85                  4                 7
# 92                  4               305
# 131                 2               310
# 102                 5               255
# 44                  2               287
# 121                 5               318
# 124                 3               230
# 75                  5               288
# 81                  4               350
#
# [20 rows x 47 columns]

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137 entries, 35 to 21
# Data columns (total 47 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                137 non-null    int64
#  1   City              137 non-null    category
#  2   City Group        137 non-null    category
#  3   Type              137 non-null    category
#  4   P1                137 non-null    int64
#  5   P2                137 non-null    float64
#  6   P3                137 non-null    float64
#  7   P4                137 non-null    float64
#  8   P5                137 non-null    int64
#  9   P6                137 non-null    int64
#  10  P7                137 non-null    int64
#  11  P8                137 non-null    int64
#  12  P9                137 non-null    int64
#  13  P10               137 non-null    int64
#  14  P11               137 non-null    int64
#  15  P12               137 non-null    int64
#  16  P13               137 non-null    float64
#  17  P14               137 non-null    int64
#  18  P15               137 non-null    int64
#  19  P16               137 non-null    int64
#  20  P17               137 non-null    int64
#  21  P18               137 non-null    int64
#  22  P19               137 non-null    int64
#  23  P20               137 non-null    int64
#  24  P21               137 non-null    int64
#  25  P22               137 non-null    int64
#  26  P23               137 non-null    int64
#  27  P24               137 non-null    int64
#  28  P25               137 non-null    int64
#  29  P26               137 non-null    float64
#  30  P27               137 non-null    float64
#  31  P28               137 non-null    float64
#  32  P29               137 non-null    float64
#  33  P30               137 non-null    int64
#  34  P31               137 non-null    int64
#  35  P32               137 non-null    int64
#  36  P33               137 non-null    int64
#  37  P34               137 non-null    int64
#  38  P35               137 non-null    int64
#  39  P36               137 non-null    int64
#  40  P37               137 non-null    int64
#  41  revenue           137 non-null    float64
#  42  reveuneYear       137 non-null    int64
#  43  revenueMonth      137 non-null    int64
#  44  revenueDay        137 non-null    int64
#  45  revenueDayofweek  137 non-null    int64
#  46  revenueDayofyear  137 non-null    int64
# dtypes: category(3), float64(9), int64(35)
# memory usage: 50.3 KB

# %%
# Convert categorial objects to numbers
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_tmp[label] = pd.Categorical(content).codes+1

# %%
df_tmp.head().T
# Out:
#                         35         122        28         112        64
# Id                     35.0      122.0       28.0      112.0       64.0
# City                    1.0       32.0       32.0       32.0       32.0
# City Group              2.0        1.0        1.0        1.0        1.0
# Type                    3.0        3.0        3.0        3.0        3.0
# P1                      4.0       12.0        4.0        4.0       12.0
# P2                      5.0        7.5        5.0        5.0        7.5
# P3                      4.0        6.0        4.0        5.0        6.0
# P4                      3.0        7.5        4.0        4.0        6.0
# P5                      1.0        2.0        1.0        1.0        2.0
# P6                      2.0        8.0        3.0        5.0        8.0
# P7                      5.0       10.0        5.0        5.0       10.0
# P8                      4.0        8.0        5.0        5.0       10.0
# P9                      4.0        8.0        4.0        4.0       10.0
# P10                     5.0        8.0        4.0        4.0       10.0
# P11                     5.0       10.0        2.0        2.0        4.0
# P12                     4.0        6.0        4.0        4.0       10.0
# P13                     5.0        6.0        4.0        4.0        7.5
# P14                     2.0       15.0        3.0        3.0       15.0
# P15                     2.0        8.0        4.0        4.0       10.0
# P16                     4.0       12.0        4.0        2.0       15.0
# P17                     2.0        6.0        2.0        1.0       15.0
# P18                     4.0        9.0        4.0        4.0       12.0
# P19                     5.0       25.0        5.0        2.0       10.0
# P20                     5.0       15.0        5.0        3.0        9.0
# P21                     4.0        9.0        2.0        2.0        6.0
# P22                     3.0        5.0        4.0        2.0        3.0
# P23                     5.0       15.0        3.0        1.0        5.0
# P24                     3.0        6.0        5.0        3.0       10.0
# P25                     3.0       10.0        3.0        3.0       10.0
# P26                     3.0       10.0        4.0        4.0       12.5
# P27                     4.0        5.0        2.0        5.0        5.0
# P28                     3.0       12.5        4.0        3.0        5.0
# P29                     2.0        2.5        2.0        3.0        7.5
# P30                     4.0       25.0        3.0        3.0       20.0
# P31                     1.0       15.0        5.0        2.0       15.0
# P32                     3.0       25.0        5.0        1.0       25.0
# P33                     3.0        6.0        2.0        2.0        4.0
# P34                     3.0       18.0        3.0        2.0       24.0
# P35                     4.0        3.0        5.0        1.0       15.0
# P36                     3.0       16.0        4.0        3.0       20.0
# P37                     3.0        6.0        4.0        3.0        6.0
# revenue           3903884.0  4286645.0  4705945.0  3784230.0  2551252.0
# reveuneYear          1996.0     1997.0     1998.0     1998.0     1998.0
# revenueMonth            5.0        4.0        1.0        3.0        7.0
# revenueDay              8.0       10.0       28.0       14.0       13.0
# revenueDayofweek        2.0        3.0        2.0        5.0        0.0
# revenueDayofyear      129.0      100.0       28.0       73.0      194.0

# %% [markdown]
# ## Read test data

# %%
df_test = pd.read_csv("restaurant-data/test.csv",
                     low_memory=False,
                     parse_dates=["Open Date"])

# %%
df_test.head().T
# Out:
#                               0                    1                    2  \
# Id                            0                    1                    2
# Open Date   2011-01-22 00:00:00  2011-03-18 00:00:00  2013-10-30 00:00:00
# City                      Niğde                Konya               Ankara
# City Group                Other                Other           Big Cities
# Type                         FC                   IL                   FC
# P1                            1                    3                    3
# P2                            4                    4                    4
# P3                            4                    4                    4
# P4                            4                    4                    4
# P5                            1                    2                    2
# P6                            2                    2                    2
# P7                            5                    5                    5
# P8                            4                    3                    4
# P9                            5                    4                    4
# P10                           5                    4                    5
# P11                           5                    2                    4
# P12                           3                    4                    5
# P13                           4                    5                    5
# P14                           0                    0                    0
# P15                           0                    0                    0
# P16                           0                    0                    0
# P17                           2                    0                    0
# P18                           0                    0                    0
# P19                           5                    5                    5
# P20                           5                    5                    5
# P21                           3                    3                    5
# P22                           1                    2                    5
# P23                           4                    1                    5
# P24                           0                    0                    0
# P25                           0                    0                    0
# P26                           0                    0                    0
# P27                           0                    0                    0
# P28                           2                    1                    2
# P29                           3                    3                    3
# P30                           0                    0                    0
# P31                           0                    0                    0
# P32                           0                    0                    0
# P33                           0                    0                    0
# P34                           0                    0                    0
# P35                           0                    0                    0
# P36                           0                    0                    0
# P37                           0                    0                    0
#
#                               3                    4
# Id                            3                    4
# Open Date   2013-05-06 00:00:00  2013-07-31 00:00:00
# City                    Kocaeli       Afyonkarahisar
# City Group                Other                Other
# Type                         IL                   FC
# P1                            2                    2
# P2                            4                    4
# P3                            4                    4
# P4                            4                    4
# P5                            2                    1
# P6                            3                    2
# P7                            5                    5
# P8                            4                    4
# P9                            5                    5
# P10                           4                    4
# P11                           3                    3
# P12                           4                    5
# P13                           5                    4
# P14                           0                    0
# P15                           0                    0
# P16                           0                    0
# P17                           0                    0
# P18                           4                    0
# P19                           4                    1
# P20                           4                    5
# P21                           3                    3
# P22                           2                    1
# P23                           2                    1
# P24                           0                    0
# P25                           0                    0
# P26                           0                    0
# P27                           0                    0
# P28                           2                    5
# P29                           3                    3
# P30                           0                    0
# P31                           4                    0
# P32                           0                    0
# P33                           0                    0
# P34                           0                    0
# P35                           0                    0
# P36                           0                    0
# P37                           0                    0

# %%
df_test.isna().sum()
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# dtype: int64

# %%
# Sort dataframe by open date
df_test.sort_values(by=["Open Date"], inplace=True, ascending=True)
df_test['Open Date'].head(20)
# Out:
# 16457   1995-05-08
# 93003   1995-05-08
# 70787   1995-05-08
# 50778   1995-05-08
# 32290   1995-05-08
# 69385   1995-05-08
# 27707   1995-05-08
# 23269   1995-05-08
# 52821   1995-05-08
# 32261   1995-05-08
# 36717   1995-05-08
# 23223   1995-05-08
# 32192   1995-05-08
# 43599   1995-05-08
# 56922   1995-05-08
# 9537    1995-05-08
# 1775    1995-05-08
# 98709   1995-05-08
# 52879   1995-05-08
# 7256    1995-05-08
# Name: Open Date, dtype: datetime64[ns]

# %%
# Add datetime parameters for saledate
df_test["reveuneYear"] = df_test['Open Date'].dt.year
df_test["revenueMonth"] = df_test['Open Date'].dt.month
df_test["revenueDay"] = df_test['Open Date'].dt.day
df_test["revenueDayofweek"] = df_test['Open Date'].dt.dayofweek
df_test["revenueDayofyear"] = df_test['Open Date'].dt.dayofyear

# Drop original saledate
df_test.drop("Open Date", axis=1, inplace=True)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 16457 to 9575
# Data columns (total 46 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                100000 non-null  int64
#  1   City              100000 non-null  object
#  2   City Group        100000 non-null  object
#  3   Type              100000 non-null  object
#  4   P1                100000 non-null  int64
#  5   P2                100000 non-null  float64
#  6   P3                100000 non-null  float64
#  7   P4                100000 non-null  float64
#  8   P5                100000 non-null  int64
#  9   P6                100000 non-null  int64
#  10  P7                100000 non-null  int64
#  11  P8                100000 non-null  int64
#  12  P9                100000 non-null  int64
#  13  P10               100000 non-null  int64
#  14  P11               100000 non-null  int64
#  15  P12               100000 non-null  int64
#  16  P13               100000 non-null  float64
#  17  P14               100000 non-null  int64
#  18  P15               100000 non-null  int64
#  19  P16               100000 non-null  int64
#  20  P17               100000 non-null  int64
#  21  P18               100000 non-null  int64
#  22  P19               100000 non-null  int64
#  23  P20               100000 non-null  int64
#  24  P21               100000 non-null  int64
#  25  P22               100000 non-null  int64
#  26  P23               100000 non-null  int64
#  27  P24               100000 non-null  int64
#  28  P25               100000 non-null  int64
#  29  P26               100000 non-null  float64
#  30  P27               100000 non-null  float64
#  31  P28               100000 non-null  float64
#  32  P29               100000 non-null  float64
#  33  P30               100000 non-null  int64
#  34  P31               100000 non-null  int64
#  35  P32               100000 non-null  int64
#  36  P33               100000 non-null  int64
#  37  P34               100000 non-null  int64
#  38  P35               100000 non-null  int64
#  39  P36               100000 non-null  int64
#  40  P37               100000 non-null  int64
#  41  reveuneYear       100000 non-null  int64
#  42  revenueMonth      100000 non-null  int64
#  43  revenueDay        100000 non-null  int64
#  44  revenueDayofweek  100000 non-null  int64
#  45  revenueDayofyear  100000 non-null  int64
# dtypes: float64(8), int64(35), object(3)
# memory usage: 35.9+ MB

# %%
for label, content in df_test.items():
    if pd.api.types.is_string_dtype(content):
        df_test[label] = content.astype("category").cat.as_ordered()

for label, content in df_test.items():
    if not pd.api.types.is_numeric_dtype(content):
        df_test[label] = pd.Categorical(content).codes+1

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 16457 to 9575
# Data columns (total 46 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                100000 non-null  int64
#  1   City              100000 non-null  int8
#  2   City Group        100000 non-null  int8
#  3   Type              100000 non-null  int8
#  4   P1                100000 non-null  int64
#  5   P2                100000 non-null  float64
#  6   P3                100000 non-null  float64
#  7   P4                100000 non-null  float64
#  8   P5                100000 non-null  int64
#  9   P6                100000 non-null  int64
#  10  P7                100000 non-null  int64
#  11  P8                100000 non-null  int64
#  12  P9                100000 non-null  int64
#  13  P10               100000 non-null  int64
#  14  P11               100000 non-null  int64
#  15  P12               100000 non-null  int64
#  16  P13               100000 non-null  float64
#  17  P14               100000 non-null  int64
#  18  P15               100000 non-null  int64
#  19  P16               100000 non-null  int64
#  20  P17               100000 non-null  int64
#  21  P18               100000 non-null  int64
#  22  P19               100000 non-null  int64
#  23  P20               100000 non-null  int64
#  24  P21               100000 non-null  int64
#  25  P22               100000 non-null  int64
#  26  P23               100000 non-null  int64
#  27  P24               100000 non-null  int64
#  28  P25               100000 non-null  int64
#  29  P26               100000 non-null  float64
#  30  P27               100000 non-null  float64
#  31  P28               100000 non-null  float64
#  32  P29               100000 non-null  float64
#  33  P30               100000 non-null  int64
#  34  P31               100000 non-null  int64
#  35  P32               100000 non-null  int64
#  36  P33               100000 non-null  int64
#  37  P34               100000 non-null  int64
#  38  P35               100000 non-null  int64
#  39  P36               100000 non-null  int64
#  40  P37               100000 non-null  int64
#  41  reveuneYear       100000 non-null  int64
#  42  revenueMonth      100000 non-null  int64
#  43  revenueDay        100000 non-null  int64
#  44  revenueDayofweek  100000 non-null  int64
#  45  revenueDayofyear  100000 non-null  int64
# dtypes: float64(8), int64(35), int8(3)
# memory usage: 33.9 MB

# %%
# Splitting into training and testing

X_train = df_tmp.drop("revenue", axis=1)
y_train = df_tmp.revenue

X_train.head()
# Out:
#       Id  City  City Group  Type  P1   P2   P3   P4  P5  P6  ...  P33  P34  \
# 35    35     1           2     3   4  5.0  4.0  3.0   1   2  ...    3    3
# 122  122    32           1     3  12  7.5  6.0  7.5   2   8  ...    6   18
# 28    28    32           1     3   4  5.0  4.0  4.0   1   3  ...    2    3
# 112  112    32           1     3   4  5.0  5.0  4.0   1   5  ...    2    2
# 64    64    32           1     3  12  7.5  6.0  6.0   2   8  ...    4   24
#
#      P35  P36  P37  reveuneYear  revenueMonth  revenueDay  revenueDayofweek  \
# 35     4    3    3         1996             5           8                 2
# 122    3   16    6         1997             4          10                 3
# 28     5    4    4         1998             1          28                 2
# 112    1    3    3         1998             3          14                 5
# 64    15   20    6         1998             7          13                 0
#
#      revenueDayofyear
# 35                129
# 122               100
# 28                 28
# 112                73
# 64                194
#
# [5 rows x 46 columns]

# %%
y_train
# Out:
# 35     3903884.0
# 122    4286645.0
# 28     4705945.0
# 112    3784230.0
# 64     2551252.0
#          ...
# 77     1904842.0
# 52     1763231.0
# 65     1756069.0
# 119    3780019.0
# 21     1149870.0
# Name: revenue, Length: 137, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_preds = model.predict(df_test)

# %%
y_preds
# Out:
# array([5044551.27, 4089941.14, 5593192.26, ..., 5978681.72, 6894557.15,
#        5780689.22])

# %% [markdown]
# ## Moving Forward
#
# 1. Split into valid and training to tune parameters for df_tmp
# 2. EDA to see which features can be removed
